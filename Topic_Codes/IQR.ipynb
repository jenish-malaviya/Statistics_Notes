# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("E:\Statistics\CSV Files\Mean_Median_Mode_Practice-Data.csv")

# %%
dataset
# Out:
#     EmpID    Name  Department  Age  Salary
# 0       1   Aarav       Sales   22   61048
# 1       2   Priya          IT   29   43289
# 2       3   Rohan       Sales   43   36395
# 3       4   Sneha  Operations   35   29165
# 4       5   Kunal       Sales   24   53657
# 5       6    Isha          IT   38   28478
# 6       7   Manav  Operations   28   79987
# 7       8   Divya          IT   36   61463
# 8       9   Rahul       Sales   27   80392
# 9      10    Neha          HR   30   45379
# 10     11   Vivek          IT   32   38396
# 11     12   Pooja       Sales   34   37676
# 12     13   Arjun          HR   33   59671
# 13     14   Kriti       Sales   45   85217
# 14     15    Yash  Operations   25   74615
# 15     16  Anjali       Sales   39   63427
# 16     17   Sahil  Operations   33   50203
# 17     18   Meera       Sales   23   54871
# 18     19     Dev          HR   24   55512
# 19     20    Riya       Sales   34   61434
# 20     21  Nikhil     Finance   42   72819
# ...

# %%
dataset["Age"]
# Out:
# 0     22
# 1     29
# 2     43
# 3     35
# 4     24
# 5     38
# 6     28
# 7     36
# 8     27
# 9     30
# 10    32
# 11    34
# 12    33
# 13    45
# 14    25
# 15    39
# 16    33
# 17    23
# 18    24
# 19    34
# 20    42
# 21    33
# 22    43
# 23    41
# 24    45
# Name: Age, dtype: int64

# %%
np.percentile(dataset["Age"],25) , np.percentile(dataset["Age"],50) , np.percentile(dataset["Age"],75)
# Out:
# (np.float64(28.0), np.float64(33.0), np.float64(39.0))

# %%
dataset["Age"].min()
# Out:
# 22

# %%
dataset["Age"].max()
# Out:
# 45

# %%
dataset["Age"].median()
# Out:
# 33.0

# %%
dataset.describe()
# Out:
#            EmpID        Age        Salary
# count  25.000000  25.000000     25.000000
# mean   13.000000  33.520000  56366.840000
# std     7.359801   7.177047  15757.198465
# min     1.000000  22.000000  28478.000000
# 25%     7.000000  28.000000  45379.000000
# 50%    13.000000  33.000000  57087.000000
# 75%    19.000000  39.000000  63427.000000
# max    25.000000  45.000000  85217.000000

# %%
sns.boxplot(x = "Age",data=dataset)
plt.show()
