# %% [markdown]
# # Mean

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ar = np.array([5,4,2,4,6,2,8,9,7,0])
ar
# Out:
# array([5, 4, 2, 4, 6, 2, 8, 9, 7, 0])

# %%
np.sort(ar)
# Out:
# array([0, 2, 2, 4, 4, 5, 6, 7, 8, 9])

# %%
np.sum(ar) / 10
# Out:
# np.float64(4.7)

# %%
np.mean(ar)
# Out:
# np.float64(4.7)

# %%
dataset = pd.read_csv("E:\Statistics\Mean_Median_Mode_Practice-Data.csv")
dataset
# Out:
#     EmpID    Name  Department  Age  Salary
# 0       1   Aarav       Sales   22   61048
# 1       2   Priya          IT   29   43289
# 2       3   Rohan       Sales   43   36395
# 3       4   Sneha  Operations   35   29165
# 4       5   Kunal       Sales   24   53657
# 5       6    Isha          IT   38   28478
# 6       7   Manav  Operations   28   79987
# 7       8   Divya          IT   36   61463
# 8       9   Rahul       Sales   27   80392
# 9      10    Neha          HR   30   45379
# 10     11   Vivek          IT   32   38396
# 11     12   Pooja       Sales   34   37676
# 12     13   Arjun          HR   33   59671
# 13     14   Kriti       Sales   45   85217
# 14     15    Yash  Operations   25   74615
# 15     16  Anjali       Sales   39   63427
# 16     17   Sahil  Operations   33   50203
# 17     18   Meera       Sales   23   54871
# 18     19     Dev          HR   24   55512
# 19     20    Riya       Sales   34   61434
# 20     21  Nikhil     Finance   42   72819
# ...

# %%
# Numpy
np.mean(dataset["Salary"])
# Out:
# np.float64(56366.84)

# %%
# Pandas
dataset["Age"].mean()
# Out:
# np.float64(33.52)

# %%
mn = np.mean(dataset["Age"])

# %%
import seaborn as sns
sns.histplot(x="Age", data=dataset,bins=[i for i in range(20,45,4)])
plt.plot([mn for i in range(0,20)],[i for i in range(0,20)],c="red")
plt.show()

# %% [markdown]
# # Median

# %%
import numpy as np
import pandas as pd
dataset = pd.read_csv("E:\Statistics\Mean_Median_Mode_Practice-Data.csv")

# %%
dataset.head(5)
# Out:
#    EmpID   Name  Department  Age  Salary
# 0      1  Aarav       Sales   22   61048
# 1      2  Priya          IT   29   43289
# 2      3  Rohan       Sales   43   36395
# 3      4  Sneha  Operations   35   29165
# 4      5  Kunal       Sales   24   53657

# %%
sorted(dataset["Age"])
# Out:
# [22,
#  23,
#  24,
#  24,
#  25,
#  27,
#  28,
#  29,
#  30,
#  32,
#  33,
#  33,
#  33,
#  34,
#  34,
#  35,
#  36,
#  38,
#  39,
#  41,
#  42,
#  43,
#  43,
#  45,
#  45]

# %%
md = np.median(dataset["Age"])

# %%
md = np.median(dataset["EmpID"])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(x="Age", data=dataset,bins=[i for i in range(20,45,4)])
plt.plot([md for i in range(0,60)],[i for i in range(0,60)],c="blue")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("E:\Statistics\Mean_Median_Mode_Practice-Data.csv")
dataset
# Out:
#     EmpID    Name  Department  Age  Salary
# 0       1   Aarav       Sales   22   61048
# 1       2   Priya          IT   29   43289
# 2       3   Rohan       Sales   43   36395
# 3       4   Sneha  Operations   35   29165
# 4       5   Kunal       Sales   24   53657
# 5       6    Isha          IT   38   28478
# 6       7   Manav  Operations   28   79987
# 7       8   Divya          IT   36   61463
# 8       9   Rahul       Sales   27   80392
# 9      10    Neha          HR   30   45379
# 10     11   Vivek          IT   32   38396
# 11     12   Pooja       Sales   34   37676
# 12     13   Arjun          HR   33   59671
# 13     14   Kriti       Sales   45   85217
# 14     15    Yash  Operations   25   74615
# 15     16  Anjali       Sales   39   63427
# 16     17   Sahil  Operations   33   50203
# 17     18   Meera       Sales   23   54871
# 18     19     Dev          HR   24   55512
# 19     20    Riya       Sales   34   61434
# 20     21  Nikhil     Finance   42   72819
# ...

# %%
dataset["Department"].mode()[0]
# Out:
# 'Sales'

# %%
dataset["Age"].mode()[0]
# Out:
# np.int64(33)

# %%
dataset["Age"].value_counts()
# Out:
# Age
# 33    3
# 34    2
# 43    2
# 24    2
# 45    2
# 22    1
# 42    1
# 23    1
# 39    1
# 25    1
# 30    1
# 32    1
# 29    1
# 27    1
# 36    1
# 28    1
# 38    1
# 35    1
# 41    1
# Name: count, dtype: int64

# %%
dataset["Department"].value_counts()
# Out:
# Department
# Sales         10
# IT             6
# Operations     5
# HR             3
# Finance        1
# Name: count, dtype: int64

# %%
mo = dataset["Age"].value_counts()

# %%
sns.histplot(x="Age", data=dataset,bins=[i for i in range(20,45,5)])
plt.plot([mo for i in range(0,40)],[i for i in range(0,40)],c="blue")
plt.show()
